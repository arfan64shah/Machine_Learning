# %%
import pandas as pd

dataset = pd.read_spss('Births.sav')

# %%
pd.set_option('display.max_columns', 253)

# %%
dataset.head()
# Out:
#      survey_id   fkey  baby_id           p3 p3_other  \
# 0  225678937.0   13-1      1.0  At hospital
# 1  225678937.0   13-1      2.0  At hospital
# 2  225528191.0  13-11      1.0      At home
# 3  225528191.0  13-11      2.0  At hospital
# 4  225528191.0  13-11      3.0  At hospital
#
#                                          p4  \
# 0                                    Doctor
# 1                                    Doctor
# 2  Skilled birth attendant (nurse/ midwife)
# 3                                    Doctor
# 4                                    Doctor
#
#                                 p4_label p4_ack               p5  p5_ack   p6  \
# 0                                 Doctor         Normal delivery     NaN  Yes
# 1                                 Doctor         Normal delivery     NaN  Yes
# 2  Момодояи бомалака (ҳамшира/ акушерка)         Normal delivery     NaN  Yes
# 3                                 Духтур         Normal delivery     NaN  Yes
# ...

# %%
dataset.shape
# Out:
# (1055, 201)
